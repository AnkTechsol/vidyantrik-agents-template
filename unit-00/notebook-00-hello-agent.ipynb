# %% [markdown]
# # Unit 0 - Hello Agent
#
# **Built for Vidyantrik by Anktechsol**
#
# This notebook demonstrates a basic agent setup.

# %%
import subprocess, sys
subprocess.check_call([sys.executable, "-m", "pip", "install", "huggingface_hub"])

from huggingface_hub import HfApi

print("Hello agent from Vidyantrik!")

api = HfApi()
models = api.list_models(sort="downloads", direction=-1, limit=5)

print("\nTop 5 models by downloads:\n")
for model in models:
    print(f"  {model.id:45s}  downloads: {model.downloads:,}")
